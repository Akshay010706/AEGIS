# %%
print(1233)
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Asus/OneDrive/डेस्कटॉप/AEGIS/AEGIS/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
